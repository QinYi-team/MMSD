# %%
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import sys
import sklearn
from sklearn import metrics
import os
import pandas as pd
import time
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import logging
logging.disable(30)
from collections import  Counter
import math
import random
from fitter import Fitter
random_seed =3407
#random.seed(random_seed )  # set random seed for python
#np.random.seed(random_seed )  # set random seed for numpy
tf.random.set_seed(random_seed )  # set random seed for tensorflow-cpu
os.environ['TF_DETERMINISTIC_OPS'] = '1' # set random seed for tensorflow-gpu

# %%
tf.test.is_gpu_available()
# Out:
# True

# %%
def mix_rbf_mmd2(X, Y, sigmas=(1,), wts=None, biased=True):
    K_XX, K_XY, K_YY, d = _mix_rbf_kernel(X, Y, sigmas, wts)
    return _mmd2(K_XX, K_XY, K_YY, const_diagonal=d, biased=biased)


def _mix_rbf_kernel(X, Y, sigmas, wts=None):
    if wts is None:
        wts = [1] * len(sigmas)

    XX = tf.matmul(X, X, transpose_b=True)
    XY = tf.matmul(X, Y, transpose_b=True)
    YY = tf.matmul(Y, Y, transpose_b=True)

    X_sqnorms = tf.linalg.diag_part(XX)
    Y_sqnorms = tf.linalg.diag_part(YY)

    r = lambda x: tf.expand_dims(x, 0)
    c = lambda x: tf.expand_dims(x, 1)

    K_XX, K_XY, K_YY = 0, 0, 0
    for sigma, wt in zip(sigmas, wts):
        gamma = 1 / (2 * sigma**2)
        K_XX += wt * tf.exp(-gamma * (-2 * XX + c(X_sqnorms) + r(X_sqnorms)))
        K_XY += wt * tf.exp(-gamma * (-2 * XY + c(X_sqnorms) + r(Y_sqnorms)))
        K_YY += wt * tf.exp(-gamma * (-2 * YY + c(Y_sqnorms) + r(Y_sqnorms)))
    return K_XX, K_XY, K_YY, tf.reduce_sum(wts)
    

def _mmd2(K_XX, K_XY, K_YY, const_diagonal=False, biased=False):
    m = tf.cast(K_XX.get_shape()[0], tf.float32)
    n = tf.cast(K_YY.get_shape()[0], tf.float32)
    
    C_K_XX=tf.pow(K_XX,2)
    C_K_YY=tf.pow(K_YY,2)
    C_K_XY=tf.pow(K_XY,2)


    if biased:
        mmd2 = (tf.reduce_sum(C_K_XX) / (m * m)
              + tf.reduce_sum(C_K_YY) / (n * n)
              - 2 * tf.reduce_sum(C_K_XY) / (m * n))
    else:
        if const_diagonal is not False:
            trace_X = m * const_diagonal
            trace_Y = n * const_diagonal
        else:
            trace_X = tf.linalg.trace(C_K_XX)
            trace_Y = tf.linalg.trace(C_K_YY)

        mmd2 = ((tf.reduce_sum(C_K_XX) - trace_X) / ((m-1) * m)
              + (tf.reduce_sum(C_K_YY) - trace_Y) / ((n-1) * n)
              - 2 * tf.reduce_sum(C_K_XY) / (m* n))
    return mmd2

# %% [markdown]
# source_data=pd.read_csv(r"F:\数据集样本划分\轴承数据\cqu\data_load0_2000_channel1_test.csv").values
# source_label=pd.read_csv(r"F:\数据集样本划分\轴承数据\cqu\label_load0_2000_channel1_test.csv").values
#
# target_data=pd.read_csv(r"F:\数据集样本划分\轴承数据\cqu\data_load1_2000_channel1_test.csv").values
# target_label=pd.read_csv(r"F:\数据集样本划分\轴承数据\cqu\label_load1_2000_channel1_test.csv").values
#
# test_target_data=pd.read_csv(r"F:\数据集样本划分\轴承数据\cqu\data_load3_1000_channel1_test.csv").values
# test_target_label=pd.read_csv(r"F:\数据集样本划分\轴承数据\cqu\label_load3_1000_channel1_test.csv").values
#
# source_data.shape,source_label.shape,target_data.shape,target_label.shape,test_target_data.shape,test_target_label.shape

# %% [markdown]
# data1=np.load(r"C:\Users\帅哥泉\本人科研所用代码\DDTLN\cwrudata\48kcwru_data.npy")
# label1=np.load(r"C:\Users\帅哥泉\本人科研所用代码\DDTLN\cwrudata\48kcwru_label.npy")
#
# data2 =np.load(r"C:\Users\帅哥泉\本人科研所用代码\DDTLN\jnudatset\jnudata1000_data.npy")
# label2 =np.load(r"C:\Users\帅哥泉\本人科研所用代码\DDTLN\jnudatset\jnudata1000_label.npy")
#
# data3=pd.read_csv(r"F:\数据集样本划分\轴承数据\ewu\data.csv").values
# label3=pd.read_csv(r"F:\数据集样本划分\轴承数据\ewu\label.csv").values
#
# #target_data=pd.read_csv(r"F:\数据集样本划分\轴承数据\cqu\data_load2_1000_channel1_test.csv").values
# #target_label=pd.read_csv(r"F:\数据集样本划分\轴承数据\cqu\label_load2_1000_channel1_test.csv").values
#
# source_data=data1
# source_label=label1
#
# target_data=data2
# target_label=label2
#
# test_target_data=data2
# test_target_label=label2
#
# source_data.shape,source_label.shape,target_data.shape,target_label.shape

# %%
source_data=(source_data-source_data.min(axis=1).reshape((len(source_data),1)))/(source_data.max(axis=1).reshape((len(source_data),1))-source_data.min(axis=1).reshape((len(source_data),1)))
target_data=(target_data-target_data.min(axis=1).reshape((len(target_data),1)))/(target_data.max(axis=1).reshape((len(target_data),1))-target_data.min(axis=1).reshape((len(target_data),1)))

# %%
#扩展数据维度 （二维——三维）
source_data=tf.expand_dims(source_data,axis=-1)
target_data=tf.expand_dims(target_data,axis=-1)

# %%
#将目标域与数据域整合为一个train_dataset
train_dataset=tf.data.Dataset.from_tensor_slices((source_data,target_data,source_label,target_label))
train_dataset=train_dataset.shuffle(4000).batch(128,drop_remainder=True)

test_dataset=tf.data.Dataset.from_tensor_slices((source_data,target_data,source_label,target_label))
test_dataset=test_dataset.batch(4000,drop_remainder=True)

# %%
def Model():
    input_1=tf.keras.Input(shape=(3072,1),name='source_data')

    x=tf.keras.layers.Conv1D(filters=16,kernel_size=64,strides=16,activation='relu',padding='same',name='conv1')(input_1)
    x=tf.keras.layers.BatchNormalization(name='bn1')(x)
    x=tf.keras.layers.MaxPooling1D(pool_size=2,strides=2,padding='same',name='plool1')(x)

    x=tf.keras.layers.Conv1D(filters=32,kernel_size=3,strides=1,activation='relu',padding='same',name='conv2')(x)
    x=tf.keras.layers.BatchNormalization(name='bn2')(x)
    x=tf.keras.layers.MaxPooling1D(pool_size=2,strides=2,padding='same',name='plool2')(x)

    x=tf.keras.layers.Conv1D(filters=64,kernel_size=3,strides=1,activation='relu',padding='same',name='conv3')(x)
    x=tf.keras.layers.BatchNormalization(name='bn3')(x)
    x=tf.keras.layers.MaxPooling1D(pool_size=2,strides=2,padding='same',name='plool3')(x)

    x=tf.keras.layers.Conv1D(filters=128,kernel_size=3,strides=1,activation='relu',padding='same',name='conv4')(x)
    x=tf.keras.layers.BatchNormalization(name='bn4')(x)
    x=tf.keras.layers.MaxPooling1D(pool_size=2,strides=2,padding='same',name='plool4')(x)

    x=tf.keras.layers.Conv1D(filters=256,kernel_size=3,strides=1,activation='relu',padding='same',name='conv5')(x)
    x=tf.keras.layers.BatchNormalization(name='bn5')(x)
    x=tf.keras.layers.MaxPooling1D(pool_size=2,strides=2,padding='same',name='plool5')(x)

    x=tf.keras.layers.GlobalAveragePooling1D()(x)

    y1=tf.keras.layers.Dense(128,activation='relu',name='cl_1')(x)
    y2=tf.keras.layers.Dense(5,name='cl_2')(y1)

    model=tf.keras.Model(inputs=input_1,outputs=[y1,y2])
    
    return model

model=Model()
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# source_data (InputLayer)     [(None, 3072, 1)]         0
# _________________________________________________________________
# conv1 (Conv1D)               (None, 192, 16)           1040
# _________________________________________________________________
# bn1 (BatchNormalization)     (None, 192, 16)           64
# _________________________________________________________________
# plool1 (MaxPooling1D)        (None, 96, 16)            0
# _________________________________________________________________
# conv2 (Conv1D)               (None, 96, 32)            1568
# _________________________________________________________________
# bn2 (BatchNormalization)     (None, 96, 32)            128
# _________________________________________________________________
# plool2 (MaxPooling1D)        (None, 48, 32)            0
# ...

# %%
pre_optimizer=tf.keras.optimizers.Adam(learning_rate=0.001)
optimizer=tf.keras.optimizers.Adam(learning_rate=0.001)               #选择adam作为优化器
loss_func=tf.keras.losses.CategoricalCrossentropy(from_logits=True)   #选用交叉熵损失函数（one——hot编码，选用CategoricalCrossentropy）

# %%
#DDS  kernel=3,u=100
#CWRU-JNU kernel=3,u=50
def mmd_rbf_loss(X1,X2, bandwidths=[3]):
    kernel_loss = mix_rbf_mmd2(X1,X2, sigmas=bandwidths)
    return kernel_loss

# %%
clc_loss=tf.keras.metrics.Mean('clc_loss')                       #使用metrics创建评价指标
mvd_loss=tf.keras.metrics.Mean('mvd_loss')
pre_train_loss=tf.keras.metrics.Mean("pre_train_loss")

train_accuracy=tf.keras.metrics.CategoricalAccuracy('train_accuracy')
pre_train_accuracy=tf.keras.metrics.CategoricalAccuracy('pre_train_accuracy')

test_accuracy=tf.keras.metrics.CategoricalAccuracy('test_accuracy')

train_acc=[]
test_acc=[]
clc_loss_=[]
mvd_loss_=[]

# %%
#建立每一个batch的训练
def train_step(model, source_data,target_data,source_label,target_label):
    u=50
    with tf.GradientTape() as t:
        out1,output1 = model(source_data,training = True)                                #得到一个batch的源域数据输出
        out2,output2 = model(target_data,training = True)                                #得到一个batch的目标域域数据输出
        loss_step =u*mmd_rbf_loss(output1,output2)+loss_func(source_label,output1)        #得到总体损失函
    grads = t.gradient(loss_step, model.trainable_variables)
    
    optimizer.apply_gradients(zip(grads, model.trainable_variables))
    
    mvd_loss(u*mmd_rbf_loss(output1,output2))
    clc_loss(loss_func(source_label,output1))
    #train_loss(loss_func(source_label,output1))
    train_accuracy(source_label,output1)
    test_accuracy(target_label,output2)

    
def train(epochs):
    for epoch in range(epochs):
        for (batch, (source_data,target_data,source_label,target_label)) in enumerate(train_dataset):
            train_step(model,source_data,target_data,source_label,target_label)
        train_acc.append(train_accuracy.result())
        mvd_loss_.append(mvd_loss.result())
        clc_loss_.append(clc_loss.result())
        test_acc.append(test_accuracy.result())
        
        print('Epoch{}, mvd_loss is {:.5f}, clc_loss is {:.5f}, train_accuracy is {:.5f},test_accuracy is {:.5f}'.format(epoch+1,
                                                                                          mvd_loss.result(),
                                                                                          clc_loss.result(),           
                                                                                          train_accuracy.result(),
                                                                                          test_accuracy.result()
                                                                                                      ))
        
        mvd_loss.reset_states()
        clc_loss.reset_states()
        train_accuracy.reset_states()
        test_accuracy.reset_states()

# %%
epochs=250
train(epochs)
# Out:
# Epoch1, mvd_loss is 0.12391, clc_loss is 1.52318, train_accuracy is 0.32272,test_accuracy is 0.23778
# Epoch2, mvd_loss is 0.10432, clc_loss is 1.37132, train_accuracy is 0.43269,test_accuracy is 0.27183
# Epoch3, mvd_loss is 0.09927, clc_loss is 1.22161, train_accuracy is 0.53606,test_accuracy is 0.30889
# Epoch4, mvd_loss is 0.13740, clc_loss is 1.14103, train_accuracy is 0.60136,test_accuracy is 0.35677
# Epoch5, mvd_loss is 0.14912, clc_loss is 1.01859, train_accuracy is 0.65104,test_accuracy is 0.41266
# Epoch6, mvd_loss is 0.16374, clc_loss is 0.94353, train_accuracy is 0.69531,test_accuracy is 0.42047
# Epoch7, mvd_loss is 0.17881, clc_loss is 0.88659, train_accuracy is 0.73658,test_accuracy is 0.40505
# Epoch8, mvd_loss is 0.17700, clc_loss is 0.83180, train_accuracy is 0.76322,test_accuracy is 0.42528
# Epoch9, mvd_loss is 0.21054, clc_loss is 0.76791, train_accuracy is 0.79087,test_accuracy is 0.43910
# ...

# %% [markdown]
# string=['train_acc','test_acc','clc_loss_','mvd_loss_']
# for i in string:
#     path=r'C:\Users\帅哥泉\Desktop\MMSD\DDS\load3-0\2'
#     if os.path.exists(path)==False:
#         os.makedirs(path)
#     path=(path+r'\MMSD_{s}.csv').format(s=i)
#     data=pd.DataFrame(np.array(eval(i)))
#     data.to_csv(path,index=False)
#     plt.plot(eval(i),label=i)
#     plt.legend()
#     plt.show()

# %% [markdown]
# string=['train_acc','test_acc','clc_loss_','mvd_loss_']
# for i in string: path=r'C:\Users\帅哥泉\Desktop\MMSD\SEU-JNU(1000)\1'
#     if os.path.exists(path)==False:
#         os.makedirs(path)
#     path=(path+r'\MMDFIR_Student_{s}.csv').format(s=i)
#     data=pd.DataFrame(np.array(eval(i)))
#     data.to_csv(path,index=False)
#     plt.plot(eval(i),label=i)
#     plt.legend()
#     plt.show()

# %%
a,b,c,d,e=[],[],[],[],[]
train_acc=[]
data1,data2,label1,label2 = next(iter(test_dataset))
_,feature1= model(data1,training = True)
_,feature2= model(data2,training = True)
   

test_target_label=np.argmax(label2,axis=-1)
s=np.argmax(feature2,axis=-1)
    
for i in range(test_target_label.shape[0]):
    if test_target_label[i]==0:
        a.append(s[i])
    elif test_target_label[i]==1:
        b.append(s[i])
    elif test_target_label[i]==2:
        c.append(s[i])
    elif test_target_label[i]==3:
        d.append(s[i])
    elif test_target_label[i]==4:
        e.append(s[i])
a=np.array(a)
b=np.array(b)
c=np.array(c)
d=np.array(d)
e=np.array(e)
print(Counter(a))
print(Counter(b))
print(Counter(c))
print(Counter(d))
print(Counter(e))
# Out:
# Counter({0: 1000})
# Counter({1: 993, 2: 5, 3: 2})
# Counter({2: 994, 1: 6})
# Counter({3: 996, 2: 2, 4: 1, 1: 1})
# Counter({4: 1000})

# %% [markdown]
# string='MMSD'
# path=r'C:\Users\帅哥泉\Desktop\MMSD\DDS\t-SNE(2.8-25.2)'
# if os.path.exists(path)==False:
#     os.makedirs(path)
# pd.DataFrame(feature1.numpy()).to_csv(path+r'\{s}_source_feature.csv'.format(s=string),index=False)
# pd.DataFrame(feature2.numpy()).to_csv(path+r'\{s}_target_feature.csv'.format(s=string),index=False)

# %%
path=r'C:\Users\帅哥泉\Desktop\MMSD\Accuracy_distribution(25.2-0)'
if os.path.exists(path)==False:
    os.makedirs(path)
pd.DataFrame(feature1.numpy()).to_csv(path+r'\{s}_source_feature.csv'.format(s=epochs),index=False)
pd.DataFrame(feature2.numpy()).to_csv(path+r'\{s}_target_feature.csv'.format(s=epochs),index=False)

# %%
pca=PCA(n_components=1,random_state=200)
feature1=pca.fit_transform(feature1).squeeze()
feature2=pca.fit_transform(feature2).squeeze()
source_data_NC=feature1[:1000]
source_data_SW=feature1[1000:2000]
source_data_RC=feature1[2000:3000]
source_data_CT=feature1[3000:4000]
source_data_MT=feature1[4000:5000]
target_data_NC=feature2[:1000]
target_data_SW=feature2[1000:2000]
target_data_RC=feature2[2000:3000]
target_data_CT=feature2[3000:4000]
target_data_MT=feature2[4000:5000]




print(source_data_NC.shape,source_data_SW.shape,source_data_RC.shape,source_data_CT.shape,source_data_MT.shape,
      target_data_NC.shape,target_data_SW.shape,target_data_RC.shape,target_data_CT.shape,target_data_MT.shape,)


source_data_NC=Fitter(source_data_NC,distributions=['t','norm'])
source_data_SW=Fitter(source_data_SW,distributions=['t','norm'])
source_data_RC=Fitter(source_data_RC,distributions=['t','norm'])
source_data_CT=Fitter(source_data_CT,distributions=['t','norm'])
source_data_MT=Fitter(source_data_MT,distributions=['t','norm'])


target_data_NC=Fitter(target_data_NC,distributions=['t','norm'])
target_data_SW=Fitter(target_data_SW,distributions=['t','norm'])
target_data_RC=Fitter(target_data_RC,distributions=['t','norm'])
target_data_CT=Fitter(target_data_CT,distributions=['t','norm'])
target_data_MT=Fitter(target_data_MT,distributions=['t','norm'])


target_data_NC.fit()
source_data_NC.fit()
target_data_SW.fit()
source_data_SW.fit()
target_data_RC.fit()
source_data_RC.fit()
target_data_CT.fit()
source_data_CT.fit()
target_data_MT.fit()
source_data_MT.fit()


fig=plt.figure(dpi=1200)
font1 = {'family' : 'Times New Roman','size'   : 10}
target_data_NC.hist()
target_data_SW.hist()
target_data_RC.hist()
target_data_CT.hist()
target_data_MT.hist()
source_data_NC.hist()
source_data_SW.hist()
source_data_RC.hist()
source_data_CT.hist()
source_data_MT.hist()
plt.legend(["Load0-NC","Load0-SW","Load0-RC","Load0-CT","Load0-MT","Load4-NC","Load4-SW","Load4-RC","Load4-CT","Load4-MT"],loc='upper right',prop=font1)
plt.show()
paths=path+r'\{s}_all_distribution.svg'.format(s=epochs)
fig.savefig(paths,dpi=1200,bbox_inches='tight')
# Out:
# (1000,) (1000,) (1000,) (1000,) (1000,) (1000,) (1000,) (1000,) (1000,) (1000,)
# ...
# Fitting 2 distributions: 100%|███████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 30.40it/s]

# %%
target_data_SW.summary()
# Out:
#       sumsquare_error          aic          bic  kl_div  ks_statistic  \
# t            1.093827  1920.680159 -6797.349423     inf      0.030759
# norm        28.551271  8643.268044 -3542.238322     inf      0.358018
#
#           ks_pvalue
# t      2.944172e-01
# norm  3.001929e-115

# %%
target_data_NC.summary()
# Out:
#       sumsquare_error         aic          bic  kl_div  ks_statistic  \
# norm        35.636667  165.669559 -3320.564675     inf      0.017589
# t           35.725587  133.371319 -3311.164866     inf      0.016802
#
#       ks_pvalue
# norm   0.910937
# t      0.935733

# %%
target_data_RC.summary()
# Out:
#       sumsquare_error          aic          bic  kl_div  ks_statistic  \
# t            6.560699  1798.971503 -5005.934882     inf      0.037737
# norm       109.693098  4958.131874 -2196.253320     inf      0.388299
#
#           ks_pvalue
# t      1.129722e-01
# norm  2.948606e-136

# %%
source_data_NC.summary()
# Out:
#       sumsquare_error          aic          bic  kl_div  ks_statistic  \
# norm         5.092287  2619.519834 -5266.212751     inf      0.029193
# t            5.595155  1002.529216 -5165.130897     inf      0.028276
#
#       ks_pvalue
# norm   0.354723
# t      0.393580

# %%
source_data_RC.summary()
# Out:
#       sumsquare_error          aic          bic  kl_div  ks_statistic  \
# t            4.662835  1414.798334 -5347.408453     inf      0.022394
# norm        35.770976  7725.943952 -3316.802930     inf      0.113541
#
#          ks_pvalue
# t     6.888935e-01
# norm  1.098653e-11

# %%
source_data_SW.summary()
# Out:
#       sumsquare_error          aic          bic  kl_div  ks_statistic  \
# t            4.697924   934.637381 -5339.911258     inf      0.032419
# norm         6.763311  2709.279018 -4982.427177     inf      0.050486
#
#       ks_pvalue
# t      0.238787
# norm   0.011796
